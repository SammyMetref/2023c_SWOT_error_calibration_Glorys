# %% [markdown]
# ![header](../figures/logos_partenaires._cmems_se.jpg)

# %% [markdown]
# # CER method for SWOT error calibration
#
# <div style="text-align: right"><i> 2022-08-24 DEMO_BASELINE </i></div>
#
# ***
# **Authors:**  Datlas, IGE, IMT-Atlantique & CLS <br>
# **Copyright:** 2022 Datlas, IGE, IMT-Atlantique & CLS <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center>CER calibration method (see Metref et al., 2019) </center></h1></div>

# %%
import os
import glob
import sys
import numpy as np
sys.path.append('..')
from src.swot import * 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Downloading data challenge inputs </h2>
#
# </div>

# %%
# Check if inputs have already been downloaded otherwise do
if len(os.listdir('../inputs'))<2:
    # Get pseuso-observation
    print('Downloading and unzipping inputs')
    # !wget https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/ocean-data-challenges/2022c_SWOT_error_calibration_GS/dc_SWOTcalibGS_inputs.tar.gz
    # !tar -xvf dc_SWOTcalibGS_inputs.tar.gz dc_SWOTcalibGS_inputs    
    # !mv dc_SWOTcalibGS_inputs  ../inputs/    
    # !rm dc_SWOTcalibGS_inputs.tar.gz

# %%
list_of_file_inputs = sorted(glob.glob('../inputs/dc_SWOTcalib_glorys_inputs/*'))

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Preping experiment paths and repositories </h2>
#
# </div>

# %%
output_dir = '../results/calib_CERmethod_glorys'
__ = os.system(f'mkdir -p {output_dir}')

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>3. Calibrating SWOT data with CER method </h2>
#
# <h3>CER method: see Metref et al. (2019) </h3>
#
#
# </div>

# %%
# %%time
 
### Loop over each SWOT pass
for filename in list_of_file_inputs:
    print(filename)
    swt = SwotTrack(filename)#,lonlatbox=lonlatbox)  
    if np.shape(swt._dset.time)[0]<2: continue
    swt.apply_CERmethod_calib('ssh_err', 'ssh_err_calib')
    output_filename = f'{output_dir}/{os.path.basename(filename)}'
    swt.to_netcdf('all', output_filename)
# Out:
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_003.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_005.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_007.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_009.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_011.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_013.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_016.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_018.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_020.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_022.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_024.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_026.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_031.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_033.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_035.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_037.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_039.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_041.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_044.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_046.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_048.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_050.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_052.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_054.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_059.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_061.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_063.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_065.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_067.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_069.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_072.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_074.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_076.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_078.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_080.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_087.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_089.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_091.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_093.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_095.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_097.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_100.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_102.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_104.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_106.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_108.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_115.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_117.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_119.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_121.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_123.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_125.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_126.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_128.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_130.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_132.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_134.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_136.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_143.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_145.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_147.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_149.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_151.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_154.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_156.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_158.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_160.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_162.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_164.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_171.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_173.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_175.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_177.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_179.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_182.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_184.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_186.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_188.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_190.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_192.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_199.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_201.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_203.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_205.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_207.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_210.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_212.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_214.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_216.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_218.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_220.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_227.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_229.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_231.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_233.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_235.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_238.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_240.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_242.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_244.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_246.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_248.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_255.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_257.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_259.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_261.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_263.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_266.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_268.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_270.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_272.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_274.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_276.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_281.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_283.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_285.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_287.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_289.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_291.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_294.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_296.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_298.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_300.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_302.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_304.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_309.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_311.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_313.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_315.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_317.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_319.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_322.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_324.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_326.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_328.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_330.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_332.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_337.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_339.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_341.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_343.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_345.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_347.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_350.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_352.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_354.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_356.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_358.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_360.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_365.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_367.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_369.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_371.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_373.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_375.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_378.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_380.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_382.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_384.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_386.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_393.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_395.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_397.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_399.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_401.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_403.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_406.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_408.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_410.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_412.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_414.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_421.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_423.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_425.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_427.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_429.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_432.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_434.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_436.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_438.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_440.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_442.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_449.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_451.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_453.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_455.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_457.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_460.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_462.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_464.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_466.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_468.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_470.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_477.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_479.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_481.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_483.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_485.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_488.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_490.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_492.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_494.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_496.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_498.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_505.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_507.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_509.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_511.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_513.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_516.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_518.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_520.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_522.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_524.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_526.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_533.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_535.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_537.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_539.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_541.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_544.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_546.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_548.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_550.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_552.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_554.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_561.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_563.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_565.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_567.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_569.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_572.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_574.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_576.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_578.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_580.nc
# Detrending ensemble
# Running EnKF
# ../inputs/dc_SWOTcalib_glorys_inputs/dc_SWOTcalib_glorys_input_005_582.nc
# Detrending ensemble
# Running EnKF
# CPU times: user 3d 1h 31min 16s, sys: 57min 25s, total: 3d 2h 28min 41s
# Wall time: 6d 3h 55min 3s
